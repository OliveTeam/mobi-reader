# %%
# %load_ext autoreload
# %autoreload 2
import mobipy
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
parser = mobipy.PalmDBParser()

# %%
parser.parse('../data/hugo_les_miserables_cosette.prc')
# Out:
# {'headers': {'name': b'Les_Mis_233_rables_-_Tome_II_-_\x00',
#   'attributes': 0,
#   'version': 0,
#   'createdDate': 1291678943,
#   'modifiedDate': 1291678943,
#   'lastBackupDate': 0,
#   'modificationNumber': 0,
#   'appInfoID': 0,
#   'sortInfoID': 0,
#   'type': b'BOOK',
#   'creator': b'MOBI',
#   'uniqueIDseed': 214,
#   'nextRecordListID': 0,
#   'numberOfRecords': 214},
#  'records': [{'recordDataOffset': 1792, 'UniqueID': 0, 'recordAttributes': 0},
#   {'recordDataOffset': 4244, 'UniqueID': 1, 'recordAttributes': 0},
#   {'recordDataOffset': 6506, 'UniqueID': 2, 'recordAttributes': 0},
#   {'recordDataOffset': 8728, 'UniqueID': 3, 'recordAttributes': 0},
#   {'recordDataOffset': 10999, 'UniqueID': 4, 'recordAttributes': 0},
#   {'recordDataOffset': 13301, 'UniqueID': 5, 'recordAttributes': 0},
#   {'recordDataOffset': 15558, 'UniqueID': 6, 'recordAttributes': 0},
#   {'recordDataOffset': 17970, 'UniqueID': 7, 'recordAttributes': 0},
# ...
